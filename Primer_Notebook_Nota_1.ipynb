# %% [markdown]
# <a href="https://colab.research.google.com/github/jesusavilezmuneton21-ui/Prog_Civil_2026_1/blob/main/Primer_Notebook_Nota_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Universidad De Sucre
# **Facultad De Ingenieria**
#
# **Departamento De Ingeniria Civil**
#
# **Jesus Andres Avilez Muñeton:1103745560**

# %% [markdown]
# **Aspectos Basicos De La Programacion Con Python**
#
# Perfecto. Empecemos **como en un curso básico de programación aplicado a ingeniería**.
# Trabajaremos con un problema sencillo siguiendo el método:
#
# 1️⃣ **Entradas – Procesos – Salidas**
# 2️⃣ **Algoritmo**
# 3️⃣ **Pseudocódigo**
# 4️⃣ **Código en Python**
#
# ---
#
# # Problema de ingeniería (nivel básico)
#
# Un estudiante de ingeniería necesita **calcular el área de un terreno rectangular** para estimar el espacio de cultivo.
#
# La fórmula es:
#
# [
# Área = base \times altura
# ]
#
# ---
#
# # 1. Definir el algoritmo (Entradas – Procesos – Salidas)
#
# ### Entradas
#
# Datos que el programa debe recibir:
#
# * base del terreno (metros)
# * altura del terreno (metros)
#
# ### Procesos
#
# Operaciones que realizará el algoritmo:
#
# * multiplicar base × altura
#
# ### Salidas
#
# Resultado que mostrará el programa:
#
# * área del terreno en **m²**
#
# ---
#
# # 2. Algoritmo (descripción paso a paso)
#
# 1. Iniciar programa
# 2. Pedir al usuario la **base del terreno**
# 3. Pedir al usuario la **altura del terreno**
# 4. Calcular el área usando la fórmula
# 5. Mostrar el área del terreno
# 6. Finalizar programa
#
# ---
#
# # 3. Pseudocódigo
#
# ```
# Inicio
#
# Leer base
# Leer altura
#
# area = base * altura
#
# Mostrar "El área del terreno es:", area
#
# Fin
# ```
#
# ---
#
# # 4. Código en Python
#
# ```python
# # Programa para calcular el área de un terreno rectangular
#
# # Entrada de datos
# base = float(input("Ingrese la base del terreno en metros: "))
# altura = float(input("Ingrese la altura del terreno en metros: "))
#
# # Proceso (cálculo)
# area = base * altura
#
# # Salida
# print("El área del terreno es:", area, "m²")
# ```
#
# ---
#
# # 5. Ejemplo de ejecución
#
# ```
# Ingrese la base del terreno en metros: 10
# Ingrese la altura del terreno en metros: 5
#
# El área del terreno es: 50 m²
# ```
#
# ---
#
# # Conceptos de Python que estás usando
#
# | Concepto            | Ejemplo                  |
# | ------------------- | ------------------------ |
# | Variable            | `base`, `altura`, `area` |
# | Operador matemático | `*` (multiplicación)     |
# | Entrada de datos    | `input()`                |
# | Conversión numérica | `float()`                |
# | Salida              | `print()`                |
#
# ---
#
# ✅ **Ejercicio para ti (muy importante para aprender):**
#
# Modifica el programa para calcular **el perímetro del terreno**.
#
# Fórmula:
#
# [
# Perímetro = 2 \times (base + altura)
# ]
#
# Intenta escribir el pseudocódigo primero.
#
# ---
#
# 💡 Si quieres, en el siguiente paso puedo enseñarte también:
#
# * Cómo hacer **diagramas de flujo para algoritmos**
# * Cómo resolver **problemas de ingeniería agrícola con Python**
# * Cómo crear tu **primer programa de cálculo de volumen de un tanque o canal**.

# %% [markdown]
# ### ¿Qué es Python?
#
# En términos sencillos, **Python** es un lenguaje de programación de alto nivel, lo que significa que su sintaxis es muy parecida al lenguaje humano (específicamente al inglés). Para un ingeniero, sus mayores ventajas son:
#
# * **Legibilidad:** El código es fácil de leer y mantener.
# * **Versatilidad:** Sirve desde para hacer una suma simple hasta para gestionar modelos de Inteligencia Artificial o aplicaciones web con Streamlit.
# * **Comunidad:** Existen miles de "librerías" (herramientas prefabricadas) para cálculos numéricos, estadística y manejo de datos.
#
# ---
#
# ### Un primer acercamiento al código
#
# Para mostrarte cómo funciona, pensemos en un problema de ingeniería básico: **Calcular el área de un canal trapezoidal o rectangular**, o simplemente algo más cotidiano como el **cálculo de la presión hidrostática** en el fondo de un tanque.
#
# Antes de escribir código, recuerda que en programación primero definimos la **lógica** (los pasos que seguiría tu cerebro o tu calculadora).
#
# > **Reto rápido:** Si quisieras calcular la fuerza ejercida sobre una superficie ($F = P \cdot A$), ¿qué datos necesitarías pedirle al usuario y qué operación harías primero?
#
# Como estamos empezando, aquí tienes un ejemplo muy básico sobre el cálculo de la densidad de un material en un laboratorio de suelos o materiales:
#
# ```python
# # Ejemplo: Cálculo de densidad de una muestra
# # Nota: Usamos nombres de variables descriptivos
#
# def calcular_densidad(masa_kg, volumen_m3):
#     """
#     Calcula la densidad de una muestra dado su masa y volumen.
#     """
#     densidad = masa_kg / volumen_m3
#     return densidad
#
# # Datos de entrada
# masa_muestra = 5.2  # en kilogramos
# volumen_muestra = 0.002  # en metros cúbicos
#
# # Llamada a la función
# resultado_densidad = calcular_densidad(masa_muestra, volumen_muestra)
#
# print(f"La densidad de la muestra es: {resultado_densidad} kg/m3")
#
# ```
#
# ### ¿Cómo puedes probar esto?
#
# 1. Abre **Google Colab**.
# 2. Crea un "Nuevo cuaderno".
# 3. Copia y pega el código anterior en una celda de código y presiona el botón de "Play".
#
# **¿Te gustaría que intentáramos resolver juntos un pequeño algoritmo relacionado con tu carrera específica?** Dime qué estudias (Agrícola, Agroindustrial o Civil) y planteamos un problema paso a paso.
